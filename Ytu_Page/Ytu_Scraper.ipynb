# %%
import random
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_loaders import WebBaseLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from urllib.parse import urljoin, urlparse
from tqdm import tqdm
import pickle

# %%
import os
import openai
import sys
import langchain

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.environ['OPENAI_API_KEY']

langchain.debug=True

# %% [markdown]
# ### Loading URLS

# %%
# Load dictionary from the file
with open('../data/ytu_page_urls.pickle', 'rb') as handle:
    url_dict = pickle.load(handle)

# url_dict
url_dict
# Out:
# {'https://www.yildiz.edu.tr/': True,
#  'https://www.yildiz.edu.tr/#main-content': True,
#  'https://www.yildiz.edu.tr/universite': True,
#  'https://www.yildiz.edu.tr/ar-ge': True,
#  'https://www.yildiz.edu.tr/egitim': True,
#  'https://www.yildiz.edu.tr/kampus': True,
#  'https://www.yildiz.edu.tr/iletisim': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/tarihce': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/misyon-ve-vizyon': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/kampusler': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/kurumsal-kimlik': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/sayilarla-ytu': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/ytu-rektorleri': True,
#  'https://www.yildiz.edu.tr/universite/yonetim': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/rektorun-mesaji': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/rektor-yardimcilari': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/yonetim-kurulu': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/senato': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/international-advisory-board': True,
#  'https://www.yildiz.edu.tr/universite/daire-baskanliklari': True,
#  'https://www.yildiz.edu.tr/universite/koordinatorlukler': True,
#  'https://www.yildiz.edu.tr/ar-ge/yildiz-teknopark': True,
#  'https://www.yildiz.edu.tr/ar-ge/teknoloji-transfer-ofisi': True,
#  'https://www.yildiz.edu.tr/ar-ge/bap': True,
#  'https://www.yildiz.edu.tr/ar-ge/laboratuvarlar': True,
#  'https://www.yildiz.edu.tr/ar-ge/uygulama-ve-arastirma-merkezleri': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/savunma-teknolojileri': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/temiz-enerji': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/biyoteknoloji': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/dijital-teknolojiler': True,
#  'https://www.yildiz.edu.tr/egitim/akademik-birimler': True,
#  'http://www.kalite.yildiz.edu.tr/login/sys/admin/subPages/img/Y%C3%96-049-YT%C3%9C%20%C3%96%C4%9Frenci%20Dekanl%C4%B1%C4%9F%C4%B1%20Y%C3%B6nergesi.pdf': 'PDF',
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi/akran-danismanligi': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi/birinci-yil-deneyimi': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi/kultur-sanat-tasarim-spor-etkinlikleri-mentorlugu': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi/psikolojik-danismanlik-birimi': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-yaklasimi': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-yaklasimi/bologna-sureci': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-yaklasimi/akreditasyon-sureci': True,
#  'https://www.yildiz.edu.tr/egitim/koop-modeli': True,
#  'https://www.yildiz.edu.tr/egitim/koop-modeli/universite-ozel-sektor-birlikleri': True,
#  'https://www.yildiz.edu.tr/egitim/koop-modeli/ulusal-ve-uluslararasi': True,
#  'https://www.yildiz.edu.tr/egitim/surekli-egitim-merkezi': True,
#  'https://www.yildiz.edu.tr/egitim/turkce-ogretim-merkezi': True,
#  'https://www.yildiz.edu.tr/egitim/uzaktan-egitim-merkezi': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-rehberlik-ve-kariyer-merkezi': True,
#  'https://www.yildiz.edu.tr/egitim/degisim-programlari': True,
#  'https://www.yildiz.edu.tr/egitim/mezunlar': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz/davutpasa-kampusu': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz/yildiz-kampusu': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/enerji-verimliligi': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/atik-yonetimi': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/akilli-kampus-ve-dijital-donusum': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/ogrenci-kulupleri': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/konaklama-yeme-icme': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/saglik-spor': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/sanat-ve-kultur': True,
#  'https://www.yildiz.edu.tr/ar-ge/kutuphane': True,
#  'https://www.yildiz.edu.tr/iletisim/iletisim-bilgileri': True,
#  'https://www.yildiz.edu.tr/iletisim/bilgi-edinme': True,
#  'https://www.yildiz.edu.tr/#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/#highlights': True,
#  'https://www.yildiz.edu.tr/universite/haberler/buyuk-bilim-ve-teknoloji-hareketi-hayata-geciyor': True,
#  'https://www.yildiz.edu.tr/universite/haberler/radyasyon-teknolojisi-arastirma-merkezimiz-acildi': True,
#  'https://www.yildiz.edu.tr/universite/haberler/ytu-deprem-bolgesinde-calismalarina-devam-ediyor': True,
#  'https://www.yildiz.edu.tr/universite/ytu-duyurular/servis-saatleri-hk': True,
#  'https://www.yildiz.edu.tr/universite/ytu-duyurular/ekpss-20241-yerlestirme-sonucuna-gore-universitemize-yerlestirilen-adaylar': True,
#  'https://www.yildiz.edu.tr/universite/ytu-etkinlik-takvimi/grad-talks-protecting-historic-built-environment-damage-due': True,
#  'https://www.yildiz.edu.tr/akademik-takvim': True,
#  'https://www.yildiz.edu.tr/universite#main-content': True,
#  'https://www.yildiz.edu.tr/universite#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/universitelerimiz/tarihce': True,
#  'https://www.yildiz.edu.tr/universite/universitelerimiz/kampusler': True,
#  'https://www.yildiz.edu.tr/universite/universitelerimiz/rakamlarla-ytu': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/rektor-tamer-yilmazdan': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/seneto': True,
#  'https://www.yildiz.edu.tr/ar-ge#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/savunma-teknolojileri': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/temiz-enerji': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/biyoteknoloji': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/dijital-teknolojiler': True,
#  'https://www.yildiz.edu.tr/arastirma/teknoloji-transfer-ofisi': True,
#  'https://www.yildiz.edu.tr/arastirma/yildiz-teknopark': True,
#  'https://www.yildiz.edu.tr/ar-ge/bap-0': True,
#  'https://www.yildiz.edu.tr/egitim#main-content': True,
#  'https://www.yildiz.edu.tr/egitim#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller/universite-ozel-sektor-birlikleri': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller/ulusal-ve-uluslararasi-birlikleri': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller/oduller': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-ve-kurslar/yildiz-sem': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-ve-kurslar/uzem': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-ve-kurslar/ytu-tomer': True,
#  'https://www.yildiz.edu.tr/kampus#main-content': True,
#  'https://www.yildiz.edu.tr/kampus#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz/yildiz-merkez-kampusu': True,
#  'https://www.yildiz.edu.tr/kampus/ogrenci-kulupleri': True,
#  'https://www.yildiz.edu.tr/kampus/ogrenci-yasami': True,
#  'https://www.yildiz.edu.tr/kampus/konaklama-yeme-icme': True,
#  'https://www.yildiz.edu.tr/kampus/saglikli-yasam': True,
#  'https://www.yildiz.edu.tr/iletisim#main-content': True,
#  'https://www.yildiz.edu.tr/iletisim#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/iletisim/kampuslerimiz': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz#main-content': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/akademik-kadro': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/tarihce#main-content': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/tarihce#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/misyon-ve-vizyon#main-content': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/misyon-ve-vizyon#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/kampusler#main-content': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/kampusler#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/kurumsal-kimlik#main-content': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/kurumsal-kimlik#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/sayilarla-ytu#main-content': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/sayilarla-ytu#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/ytu-rektorleri#main-content': True,
#  'https://www.yildiz.edu.tr/universite/universitemiz/ytu-rektorleri#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/yonetim#main-content': True,
#  'https://www.yildiz.edu.tr/universite/yonetim#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/rektorun-mesaji#main-content': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/rektorun-mesaji#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/rektor-yardimcilari#main-content': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/rektor-yardimcilari#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/yonetim-kurulu#main-content': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/yonetim-kurulu#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/senato#main-content': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/senato#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/international-advisory-board#main-content': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/international-advisory-board#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/daire-baskanliklari#main-content': True,
#  'https://www.yildiz.edu.tr/universite/daire-baskanliklari#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/koordinatorlukler#main-content': True,
#  'https://www.yildiz.edu.tr/universite/koordinatorlukler#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/yildiz-teknopark#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/yildiz-teknopark#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/teknoloji-transfer-ofisi#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/teknoloji-transfer-ofisi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/bap#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/bap#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/laboratuvarlar#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/laboratuvarlar#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/uygulama-ve-arastirma-merkezleri#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/uygulama-ve-arastirma-merkezleri#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/savunma-teknolojileri#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/savunma-teknolojileri#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/temiz-enerji#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/temiz-enerji#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/biyoteknoloji#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/biyoteknoloji#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/dijital-teknolojiler#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/odak-teknolojiler/dijital-teknolojiler#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/akademik-birimler#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/akademik-birimler#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi/akran-danismanligi#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi/akran-danismanligi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi/birinci-yil-deneyimi#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi/birinci-yil-deneyimi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi/psikolojik-danismanlik-birimi#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-dekanligi/psikolojik-danismanlik-birimi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-yaklasimi#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-yaklasimi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-yaklasimi/bologna-sureci#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-yaklasimi/bologna-sureci#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-yaklasimi/akreditasyon-sureci#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-yaklasimi/akreditasyon-sureci#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/koop-modeli#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/koop-modeli#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/koop-modeli/universite-ozel-sektor-birlikleri#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/koop-modeli/universite-ozel-sektor-birlikleri#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/koop-modeli/ulusal-ve-uluslararasi#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/koop-modeli/ulusal-ve-uluslararasi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/surekli-egitim-merkezi#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/surekli-egitim-merkezi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/turkce-ogretim-merkezi#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/turkce-ogretim-merkezi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/uzaktan-egitim-merkezi#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/uzaktan-egitim-merkezi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-rehberlik-ve-kariyer-merkezi#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/ogrenci-rehberlik-ve-kariyer-merkezi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/degisim-programlari#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/degisim-programlari#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/mezunlar#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/mezunlar#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz/davutpasa-kampusu#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz/davutpasa-kampusu#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz/yildiz-kampusu#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz/yildiz-kampusu#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/akillim-kampus-ve-dijital-donusum': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/enerji-verimliligi#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/enerji-verimliligi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/atik-yonetimi#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/atik-yonetimi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/akilli-kampus-ve-dijital-donusum#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/akilli-kampus-ve-dijital-donusum#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/ogrenci-kulupleri#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/ogrenci-kulupleri#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/konaklama-yeme-icme#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/konaklama-yeme-icme#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/saglik-spor#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/saglik-spor#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/sanat-ve-kultur#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/kampus-yasami/sanat-ve-kultur#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/kutuphane#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/kutuphane#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/iletisim/iletisim-bilgileri#main-content': True,
#  'https://www.yildiz.edu.tr/iletisim/iletisim-bilgileri#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/iletisim/bilgi-edinme#main-content': True,
#  'https://www.yildiz.edu.tr/iletisim/bilgi-edinme#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#main-content': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-165': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-168': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-171': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-174': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-186': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-189': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-192': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-177': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-183': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-180': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-195': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-198': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-201': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-207': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-204': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-210': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-213': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-216': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-237': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-219': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-222': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-225': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-228': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-231': True,
#  'https://www.yildiz.edu.tr/akademik-takvim#academiccaclendar-234': True,
#  'https://www.yildiz.edu.tr/universite/universitelerimiz/tarihce#main-content': True,
#  'https://www.yildiz.edu.tr/universite/universitelerimiz/tarihce#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/universitelerimiz/kampusler#main-content': True,
#  'https://www.yildiz.edu.tr/universite/universitelerimiz/kampusler#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/universitelerimiz/rakamlarla-ytu#main-content': True,
#  'https://www.yildiz.edu.tr/universite/universitelerimiz/rakamlarla-ytu#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/rektor-tamer-yilmazdan#main-content': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/rektor-tamer-yilmazdan#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/seneto#main-content': True,
#  'https://www.yildiz.edu.tr/universite/yonetim/seneto#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/savunma-teknolojileri#main-content': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/savunma-teknolojileri#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/temiz-enerji#main-content': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/temiz-enerji#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/biyoteknoloji#main-content': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/biyoteknoloji#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/dijital-teknolojiler#main-content': True,
#  'https://www.yildiz.edu.tr/arastirma/odak-teknolojiler/dijital-teknolojiler#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/arastirma/teknoloji-transfer-ofisi#main-content': True,
#  'https://www.yildiz.edu.tr/arastirma/teknoloji-transfer-ofisi#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/arastirma/yildiz-teknopark#main-content': True,
#  'https://www.yildiz.edu.tr/arastirma/yildiz-teknopark#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/ar-ge/bap-0#main-content': True,
#  'https://www.yildiz.edu.tr/ar-ge/bap-0#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller/universite-ozel-sektor-birlikleri#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller/universite-ozel-sektor-birlikleri#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller/ulusal-ve-uluslararasi-birlikleri#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller/ulusal-ve-uluslararasi-birlikleri#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller/oduller#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller/oduller#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-ve-kurslar/yildiz-sem#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-ve-kurslar/yildiz-sem#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-ve-kurslar/uzem#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-ve-kurslar/uzem#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-ve-kurslar/ytu-tomer#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/egitim-ve-kurslar/ytu-tomer#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz/yildiz-merkez-kampusu#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/kampuslerimiz/yildiz-merkez-kampusu#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/ogrenci-kulupleri#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/ogrenci-kulupleri#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/ogrenci-yasami#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/ogrenci-yasami#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/konaklama-yeme-icme#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/konaklama-yeme-icme#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/kampus/saglikli-yasam#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/saglikli-yasam#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/iletisim/kampuslerimiz#main-content': True,
#  'https://www.yildiz.edu.tr/iletisim/kampuslerimiz#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/universite/akademik-kadro#main-content': True,
#  'https://www.yildiz.edu.tr/universite/akademik-kadro#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/sayfa/AKADEM%C4%B0K/AKADEM%C4%B0K-B%C4%B0R%C4%B0MLER/122': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/akillim-kampus-ve-dijital-donusum#main-content': True,
#  'https://www.yildiz.edu.tr/kampus/surdurulebilirlik/akillim-kampus-ve-dijital-donusum#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller#main-content': True,
#  'https://www.yildiz.edu.tr/egitim/birlikleri-ve-oduller#appsMenuLink': True,
#  'https://www.yildiz.edu.tr/sayfa/AKADEM%C4%B0K/AKADEM%C4%B0K-B%C4%B0R%C4%B0MLER/122#main-content': True,
#  'https://www.yildiz.edu.tr/sayfa/AKADEM%C4%B0K/AKADEM%C4%B0K-B%C4%B0R%C4%B0MLER/122#appsMenuLink': True}

# %% [markdown]
# ### Scraping

# %%
def find_longest_common_subtexts(*texts, min_length=100) -> list:
    """
    Finds the largest common substring in a list of strings.
    
    Parameters:
    - texts (tuple): Variable number of text arguments.
    - min_length (int): Minimum length of the common substring to consider it significant.
    
    Returns:
    - str: The longest common substrings found across all input texts that meets or exceeds min_length.
    """
    
    def lcs(str1, str2):
        """
        Helper function to find the longest common substring between two strings using dynamic programming.
        """
        m, n = len(str1), len(str2)
        dp = [[0] * (n+1) for _ in range(2)]
        max_length, end_pos = 0, 0
        
        for i in range(1, m+1):
            for j in range(1, n+1):
                if str1[i-1] == str2[j-1]:
                    dp[i % 2][j] = dp[(i-1) % 2][j-1] + 1
                    if dp[i % 2][j] > max_length:
                        max_length = dp[i % 2][j]
                        end_pos = i
                else:
                    dp[i % 2][j] = 0
                    
        return str1[end_pos - max_length: end_pos]
    
    def find_largest_common_subtext(texts, min_length):
        if len(texts) < 2:
            return ""
        
        common_subtext = lcs(texts[0], texts[1])
        
        for text in texts[2:]:
            if len(common_subtext) < min_length:
                return ""
            common_subtext = lcs(common_subtext, text)
            if len(common_subtext) < min_length:
                return ""
        
        return common_subtext if len(common_subtext) >= min_length else ""
    
    common_subtexts = []
    modified_texts = list(texts)
    while True:
        common_subtext = find_largest_common_subtext(modified_texts, min_length)
        if not common_subtext:
            break
        common_subtexts.append(common_subtext)
        
        modified_texts = [text.replace(common_subtext, "") for text in modified_texts]
    
    return common_subtexts



def process_urls(url_dict, random_common_docs_n=3):
    web_docs = []
    unprocessed_urls = []
    
    # Choose random pages to find the common subtext and remove them.
    random_docs = []
    while random_common_docs_n:
        url, url_type = random.choice(list(url_dict.items()))
        if url_type != 'PDF':
            try:
                random_docs.append(WebBaseLoader(url).load()[0].page_content)
                random_common_docs_n -= 1
            except Exception as e:
                print(f'Error while choosing random doc: {str(e)}')
    
    common_subtexts = find_longest_common_subtexts(*random_docs)
    
    
    # Scraping and cleaning web pages 
    for i, url in enumerate(url_dict):
        try:
            print(f'Scraping url {i+1}')
            if url_dict[url] != 'PDF':
                web_loader = WebBaseLoader(url)
                web_doc = web_loader.load()
                edited_content = web_doc[0].page_content
                
                for common_subtext in common_subtexts:
                    edited_content = edited_content.replace(common_subtext, "")
                while "\n\n\n" in edited_content:
                    edited_content = edited_content.replace("\n\n\n", "")

                    web_doc[0].page_content = edited_content
                web_docs.append(web_doc[0])
            else:
                loader = PyPDFLoader(url)
                pages = loader.load()
                edited_content = pages[0].page_content
                while "\n\n\n" in edited_content:
                    edited_content = edited_content.replace("\n\n\n", "")
                web_docs.append(pages[0])
                
        except Exception as e:
            print(f'Error scraping url {i+1}: {str(e)}')
            unprocessed_urls.append(url)

    print('Scraping Completed')
    return web_docs, unprocessed_urls



def text_splitter(web_docs):
    print('\nSplitting text ...')
    
    r_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1024, 
        chunk_overlap=256,
        separators=["\n\n", "\n", ". ", " ", ""]
    )

    splitted_docs = r_splitter.split_documents(web_docs)
    splitted_docs = [split for split in splitted_docs if len(split.page_content) > 150]
    
    print(f'Splitted chunks number: {len(splitted_docs)}\n')
    return splitted_docs



def extract_text_from_url(url):
    """
    Extract text from the end of the URL, correctly handling /text and /text/number cases.
    """
    # Extracting the path from the URL and splitting it
    path_segments = urlparse(url).path.split('/')
    # Filtering out empty segments and digits-only segments
    text_segments = [segment for segment in path_segments if segment and not segment.isdigit()]

    # The last segments in text_segments should be the text we want to extract
    if len(text_segments) >= 2:
        # If there are at least 2 elements, return the last two joined by ' / '
        return text_segments[-2] + ' / ' + text_segments[-1]
    elif len(text_segments) == 1:
        # If there's only one element, return it
        return text_segments[-1]
    else:
        # If the list is empty, return None
        return None


def add_metadata(splitted_docs):
    """
    Adds the metadata at the beginning of each document, accounting for missing title or page number.
    """
    for doc in tqdm(splitted_docs, desc="Adding metadata to documents"):
        # Initialize the metadata string
        metadata_str = f"Source: {doc.metadata['source']}\n"
        
        # Conditionally add title if it exists
        if 'title' in doc.metadata and doc.metadata['title']:
            metadata_str += f"Page Title: {doc.metadata['title']}\n"
        
        # Add subject extracted from source URL
        metadata_str += f"Subject: {extract_text_from_url(doc.metadata['source'])}\n"
        
        # Conditionally add PDF page number if it's a PDF and the page number exists
        if doc.metadata['source'].endswith('.pdf') and 'page' in doc.metadata:
            metadata_str += f"Pdf Page Number: {doc.metadata['page']}\n"
        
        # Append the updated metadata to the page content
        doc.page_content = metadata_str + "\n" + doc.page_content
    
    return splitted_docs



def enhance_meta_data(processed_docs):
    '''
    Check if the document is an anouncement/duyuru/haber document and adds
    this information to the metada. 
    '''
    for doc in tqdm(processed_docs, desc="Enhancing documents metadata"):
        if 'haberler' in doc.metadata['source']:
            doc.metadata['Type'] = 'haber'
        elif 'duyuru' in doc.metadata['source']:
            doc.metadata['Type'] = 'duyuru'
        elif 'etkinlik' in doc.metadata['source']:
            doc.metadata['Type'] = 'etkinlik'
        else:
            doc.metadata['Type'] = 'general'
            
    return processed_docs
            


def Preprocess(url_dict):
    
    web_docs, unprocessed_urls = process_urls(url_dict)
    splitted_docs = text_splitter(web_docs)
    processed_docs = add_metadata(splitted_docs)
    preprocessed_docs = enhance_meta_data(processed_docs)
    print('\nYou are done!')
    
    return preprocessed_docs


preprocessed_docs = Preprocess(url_dict)
# Out:
# Scraping url 1
# Scraping url 2
# Scraping url 3
# Scraping url 4
# Scraping url 5
# Scraping url 6
# Scraping url 7
# Scraping url 8
# Scraping url 9
# Scraping url 10
# Scraping url 11
# Scraping url 12
# Scraping url 13
# Scraping url 14
# Scraping url 15
# Scraping url 16
# Scraping url 17
# Scraping url 18
# Scraping url 19
# Scraping url 20
# Scraping url 21
# Scraping url 22
# Scraping url 23
# Scraping url 24
# Scraping url 25
# Scraping url 26
# Scraping url 27
# Scraping url 28
# Scraping url 29
# Scraping url 30
# Scraping url 31
# Scraping url 32
# Scraping url 33
# Scraping url 34
# Scraping url 35
# Scraping url 36
# Scraping url 37
# Scraping url 38
# Scraping url 39
# Scraping url 40
# Scraping url 41
# Scraping url 42
# Scraping url 43
# Scraping url 44
# Scraping url 45
# Scraping url 46
# Scraping url 47
# Scraping url 48
# Scraping url 49
# Scraping url 50
# Scraping url 51
# Scraping url 52
# Scraping url 53
# Scraping url 54
# Scraping url 55
# Scraping url 56
# Scraping url 57
# Scraping url 58
# Scraping url 59
# Scraping url 60
# Scraping url 61
# Scraping url 62
# Scraping url 63
# Scraping url 64
# Scraping url 65
# Scraping url 66
# Scraping url 67
# Scraping url 68
# Scraping url 69
# Scraping url 70
# Scraping url 71
# Scraping url 72
# Scraping url 73
# Scraping url 74
# Scraping url 75
# Scraping url 76
# Scraping url 77
# Scraping url 78
# Scraping url 79
# Scraping url 80
# Scraping url 81
# Scraping url 82
# Scraping url 83
# Scraping url 84
# Scraping url 85
# Scraping url 86
# Scraping url 87
# Scraping url 88
# Scraping url 89
# Scraping url 90
# Scraping url 91
# Scraping url 92
# Scraping url 93
# Scraping url 94
# Scraping url 95
# Scraping url 96
# Scraping url 97
# Scraping url 98
# Scraping url 99
# Scraping url 100
# Scraping url 101
# Scraping url 102
# Scraping url 103
# Scraping url 104
# Scraping url 105
# Scraping url 106
# Scraping url 107
# Scraping url 108
# Scraping url 109
# Scraping url 110
# Scraping url 111
# Scraping url 112
# Scraping url 113
# Scraping url 114
# Scraping url 115
# Scraping url 116
# Scraping url 117
# Scraping url 118
# Scraping url 119
# Scraping url 120
# Scraping url 121
# Scraping url 122
# Scraping url 123
# Scraping url 124
# Scraping url 125
# Scraping url 126
# Scraping url 127
# Scraping url 128
# Scraping url 129
# Scraping url 130
# Scraping url 131
# Scraping url 132
# Scraping url 133
# Scraping url 134
# Scraping url 135
# Scraping url 136
# Scraping url 137
# Scraping url 138
# Scraping url 139
# Scraping url 140
# Scraping url 141
# Scraping url 142
# Scraping url 143
# Scraping url 144
# Scraping url 145
# Scraping url 146
# Scraping url 147
# Scraping url 148
# Scraping url 149
# Scraping url 150
# Scraping url 151
# Scraping url 152
# Scraping url 153
# Scraping url 154
# Scraping url 155
# Scraping url 156
# Scraping url 157
# Scraping url 158
# Scraping url 159
# Scraping url 160
# Scraping url 161
# Scraping url 162
# Scraping url 163
# Scraping url 164
# Scraping url 165
# Scraping url 166
# Scraping url 167
# Scraping url 168
# Scraping url 169
# Scraping url 170
# Scraping url 171
# Scraping url 172
# Scraping url 173
# Scraping url 174
# Scraping url 175
# Scraping url 176
# Scraping url 177
# Scraping url 178
# Scraping url 179
# Scraping url 180
# Scraping url 181
# Scraping url 182
# Scraping url 183
# Scraping url 184
# Scraping url 185
# Scraping url 186
# Scraping url 187
# Scraping url 188
# Scraping url 189
# Scraping url 190
# Scraping url 191
# Scraping url 192
# Scraping url 193
# Scraping url 194
# Scraping url 195
# Scraping url 196
# Scraping url 197
# Scraping url 198
# Scraping url 199
# Scraping url 200
# Scraping url 201
# Scraping url 202
# Scraping url 203
# Scraping url 204
# Scraping url 205
# Scraping url 206
# Scraping url 207
# Scraping url 208
# Scraping url 209
# Scraping url 210
# Scraping url 211
# Scraping url 212
# Scraping url 213
# Scraping url 214
# Scraping url 215
# Scraping url 216
# Scraping url 217
# Scraping url 218
# Scraping url 219
# Scraping url 220
# Scraping url 221
# Scraping url 222
# Scraping url 223
# Scraping url 224
# Scraping url 225
# Scraping url 226
# Scraping url 227
# Scraping url 228
# Scraping url 229
# Scraping url 230
# Scraping url 231
# Scraping url 232
# Scraping url 233
# Scraping url 234
# Scraping url 235
# Scraping url 236
# Scraping url 237
# Scraping url 238
# Scraping url 239
# Scraping url 240
# Scraping url 241
# Scraping url 242
# Scraping url 243
# Scraping url 244
# Scraping url 245
# Scraping url 246
# Scraping url 247
# Scraping url 248
# Scraping url 249
# Scraping url 250
# Scraping url 251
# Scraping url 252
# Scraping url 253
# Scraping url 254
# Scraping url 255
# Scraping url 256
# Scraping url 257
# Scraping url 258
# Scraping url 259
# Scraping url 260
# Scraping url 261
# Scraping url 262
# Scraping url 263
# Scraping url 264
# Scraping url 265
# Scraping url 266
# Scraping url 267
# Scraping url 268
# Scraping url 269
# Scraping url 270
# Scraping url 271
# Scraping url 272
# Scraping url 273
# Scraping url 274
# Scraping url 275
# Scraping url 276
# Scraping url 277
# Scraping url 278
# Scraping url 279
# Scraping url 280
# Scraping url 281
# Scraping url 282
# Scraping url 283
# Scraping url 284
# Scraping url 285
# Scraping url 286
# Scraping url 287
# Scraping url 288
# Scraping url 289
# Scraping url 290
# Scraping url 291
# Scraping url 292
# Scraping url 293
# Scraping url 294
# Scraping url 295
# Scraping url 296
# Scraping url 297
# Scraping url 298
# Scraping url 299
# Scraping url 300
# Scraping url 301
# Scraping url 302
# Scraping url 303
# Scraping url 304
# Scraping url 305
# Scraping url 306
# Scraping url 307
# Scraping url 308
# Scraping url 309
# Scraping url 310
# Scraping Completed
#
# Splitting text ...
# Splitted chunks number: 1542
# Adding metadata to documents: 100%|█████| 1542/1542 [00:00<00:00, 213248.60it/s]
# Enhancing documents metadata: 100%|████| 1542/1542 [00:00<00:00, 2126805.91it/s]
# You are done!

# %%
print(preprocessed_docs[100].page_content)
print('\n----------------------\n')
print(preprocessed_docs[100].metadata)
# Out:
# Source: https://www.yildiz.edu.tr/universite/yonetim/yonetim-kurulu
# Page Title: Yönetim Kurulu | Yıldız Teknik Üniversitesi
# Subject: yonetim / yonetim-kurulu
#
# Üniversite Yönetim Kurulu, üniversitenin idari konularda en üst karar organıdır. Üniversite yönetim kurulu, rektörün başkanlığında, dekanlar, ve enstitü müdürleri ile meslek yüksekokulları müdürlerinin kendi aralarından seçeceği bir müdürden oluşur. Rektör yardımcıları ve genel sekreter oy hakkı olmaksızın toplantılara katılır ve genel sekreter raportörlük yapar
#
# ----------------------
#
# {'source': 'https://www.yildiz.edu.tr/universite/yonetim/yonetim-kurulu', 'title': 'Yönetim Kurulu | Yıldız Teknik Üniversitesi', 'language': 'tr', 'Type': 'general'}

# %% [markdown]
# ## Vectorstores

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

embedding = OpenAIEmbeddings()

vectordb = Chroma.from_documents(
    documents=preprocessed_docs,
    embedding=embedding,
    persist_directory='../db/ytu_website'
)
vectordb.persist()

# vectordb = Chroma(persist_directory='./db/...', embedding_function=embedding)

# %%
# vectordb.persist()
