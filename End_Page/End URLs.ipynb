# %%
from urllib.parse import urljoin, urlparse
from collections import deque
import requests
from bs4 import BeautifulSoup
import re
import fitz

# %%
class WebUrlFetcher:
    def __init__(self, start_url, base_url, unvalid_urls, unvalid_pdf_words, max_haber_number=3, max_duyuru_number=3, max_etkinlik_number=3, text_density=500):
        self.fetched_urls = {}
        self.urls_to_fetch = [start_url]
        self.base_url = base_url
        self.unvalid_urls = unvalid_urls
        self.unvalid_pdf_words = unvalid_pdf_words
        self.max_haber_number = max_haber_number
        self.max_duyuru_number = max_duyuru_number
        self.max_etkinlik_number = max_etkinlik_number
        self.text_density = text_density

    def is_valid_url(self, url):
        if self.base_url in url and not any(unvalid in url for unvalid in self.unvalid_urls):
            return True
        return False

    def normalize_url(self, url, parent_url):
        return urljoin(parent_url, url)

    def analyze_pdf_content(self, url):
        try:
            response = requests.get(url)
            with fitz.open(stream=response.content, filetype="pdf") as doc:
                total_chars = 0
                for page in doc:
                    text = page.get_text()
                    total_chars += len(text)
                avg_chars_per_page = total_chars / len(doc) if doc.page_count > 0 else 0
            return avg_chars_per_page
        except Exception as e:
            print(f"Error processing {url}: {e}")
            return 0  # Return 0 instead of None to allow comparisons

    def is_valid_pdf_url(self, url):
        avg_chars_per_page = self.analyze_pdf_content(url)
        return not any(word in url for word in self.unvalid_pdf_words) and (avg_chars_per_page is not None and avg_chars_per_page >= self.text_density)

    def fetch_url(self, url):
        if url in self.fetched_urls:
            return

        print(f"Fetching URL: {url}")
        try:
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')

            for link in soup.find_all('a', href=True):
                normalized_url = self.normalize_url(link['href'], url)

                if self.is_valid_url(normalized_url) and normalized_url not in self.fetched_urls:
                    self.urls_to_fetch.append(normalized_url)

                elif 'haberler' in normalized_url and self.max_haber_number > 0:
                    self.urls_to_fetch.append(normalized_url)
                    self.max_haber_number -= 1

                elif 'duyurular' in normalized_url and self.max_duyuru_number > 0:
                    self.urls_to_fetch.append(normalized_url)
                    self.max_duyuru_number -= 1

                elif 'etkinlik' in normalized_url and self.max_etkinlik_number > 0:
                    self.urls_to_fetch.append(normalized_url)
                    self.max_etkinlik_number -= 1

                elif normalized_url.endswith('.pdf') and self.is_valid_pdf_url(normalized_url):
                    self.fetched_urls[normalized_url] = 'PDF'

            self.fetched_urls[url] = True
        except Exception as e:
            print(f"Failed to fetch {url} due to {e}")

    def fetch(self):
        while self.urls_to_fetch:
            url = self.urls_to_fetch.pop(0)
            self.fetch_url(url)

        return self.fetched_urls

# %%
# Initialize data structures
start_url = 'https://enm.yildiz.edu.tr/'
base_url = '/enm.yildiz.edu.tr'
unvalid_urls = ['enm.yildiz.edu.tr/en', '/haberler', '/files', '/etkinlik', '/duyuru', '.com']
unvalid_pdf_words=[]
max_haber_number = 3
max_duyuru_number = 3
max_etkinlik_number = 3

# ----------------------
# Note: Function calls and method calls are commented out to adhere to instructions.
# To use this class, instantiate it with the necessary parameters and call the `scrape` method.
# Example:
fetcher = WebUrlFetcher(start_url=start_url, base_url=base_url,
                     unvalid_urls=unvalid_urls, unvalid_pdf_words=unvalid_pdf_words)
fetched_urls = fetcher.fetch()
# Out:
# Fetching URL: https://enm.yildiz.edu.tr/
# Fetching URL: https://enm.yildiz.edu.tr/#main-content
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/aday-ogrenciler
# Error processing https://www.yildiz.edu.tr/media/files/Y%C4%B1ld%C4%B1z%20Teknik%20%C3%9Cniversitesi%20Tan%C4%B1t%C4%B1m%20Katalo%C4%9Fu.pdf: cannot open broken document
# Error processing https://www.yildiz.edu.tr/media/files/makine_fakultesi(5).pdf: cannot open broken document
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/bolum-baskanligimiz
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/ders-program-ciktilari-matrisi
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/ders-plan-ve-icerikleri
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/egitim-amaclarimiz
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/misyon-ve-vizyonumuz
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/program-ciktilarimiz
# Fetching URL: https://enm.yildiz.edu.tr/kisiler
# Fetching URL: https://enm.yildiz.edu.tr/kisiler/tam-zamanli-ogretim-uyeleri
# Fetching URL: https://enm.yildiz.edu.tr/kisiler/arastirma-gorevlileri
# Fetching URL: https://enm.yildiz.edu.tr/kisiler/muhendisler
# Fetching URL: https://enm.yildiz.edu.tr/lisans
# Fetching URL: https://enm.yildiz.edu.tr/lisans/bolum-komisyonlari
# Fetching URL: https://enm.yildiz.edu.tr/lisans/erasmus
# Fetching URL: https://enm.yildiz.edu.tr/lisans/tezproje-yazim-klavuzlari
# Fetching URL: https://enm.yildiz.edu.tr/lisans/ogrenci-temsilciligi
# Fetching URL: https://enm.yildiz.edu.tr/lisans/intibak-basvurulari
# Fetching URL: https://enm.yildiz.edu.tr/lisans/formlar
# Fetching URL: https://enm.yildiz.edu.tr/lisans/staj-genel-bilgiler
# Error processing http://www.enm.yildiz.edu.tr/images/files/MASII_Instructions_EN_20072020.pdf: cannot open broken document
# Error processing file:///C:/Users/Supervisor/Downloads/MAKSTAJ_036%20(1).pdf: No connection adapters were found for 'file:///C:/Users/Supervisor/Downloads/MAKSTAJ_036%20(1).pdf'
# Fetching URL: https://enm.yildiz.edu.tr/lisans/atolye-staji
# Fetching URL: https://enm.yildiz.edu.tr/lisans/mesleki-alan-staji-2
# Error processing file:///sites/enm.yildiz.edu.tr/images/files/MAS-II%20Yonerge%20Ingilizce.pdf: No connection adapters were found for 'file:///sites/enm.yildiz.edu.tr/images/files/MAS-II%20Yonerge%20Ingilizce.pdf'
# Fetching URL: https://enm.yildiz.edu.tr/lisans/staj-uygulama-ilkeleri
# Fetching URL: https://enm.yildiz.edu.tr/lisansustu
# Fetching URL: https://enm.yildiz.edu.tr/lisansustu/bilimsel-hazirlik-dersleri
# Fetching URL: https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/images/Bilimsel%20Haz%C4%B1rl%C4%B1k%20Dersleri.pdf
# Fetching URL: https://enm.yildiz.edu.tr/lisansustu/yonetmelikler-0
# Fetching URL: https://enm.yildiz.edu.tr/duyurular/necdet-tirilin-dikkatine
# Fetching URL: https://enm.yildiz.edu.tr/duyurular/erasmus-surecleri-bilgilendirme-toplantisi-0
# Fetching URL: https://enm.yildiz.edu.tr/etkinlikler/case-point-vaka-analizi-yarismasi-ytu-mentorluk-kulubu
# Fetching URL: https://enm.yildiz.edu.tr/etkinlikler/when-stars-alignytu-mentorluk-kulubu
# Fetching URL: https://enm.yildiz.edu.tr/adaylar
# Fetching URL: https://enm.yildiz.edu.tr/ogrenci-bilgi-sistemleri
# Fetching URL: https://enm.yildiz.edu.tr/akademik-takvim
# Fetching URL: https://enm.yildiz.edu.tr/ders-programlari
# Fetching URL: https://enm.yildiz.edu.tr/sinav-programlari
# Fetching URL: https://enm.yildiz.edu.tr/akreditasyon
# Fetching URL: https://enm.yildiz.edu.tr/staj-ve-imkanlari
# Fetching URL: https://enm.yildiz.edu.tr/koop
# Fetching URL: https://enm.yildiz.edu.tr/iletisim
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda#main-content
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/aday-ogrenciler#main-content
# Error processing https://www.yildiz.edu.tr/media/files/Y%C4%B1ld%C4%B1z%20Teknik%20%C3%9Cniversitesi%20Tan%C4%B1t%C4%B1m%20Katalo%C4%9Fu.pdf: cannot open broken document
# Error processing https://www.yildiz.edu.tr/media/files/makine_fakultesi(5).pdf: cannot open broken document
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/bolum-baskanligimiz#main-content
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/ders-program-ciktilari-matrisi#main-content
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/ders-plan-ve-icerikleri#main-content
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/egitim-amaclarimiz#main-content
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/misyon-ve-vizyonumuz#main-content
# Fetching URL: https://enm.yildiz.edu.tr/hakkimizda/program-ciktilarimiz#main-content
# Fetching URL: https://enm.yildiz.edu.tr/kisiler#main-content
# Fetching URL: https://enm.yildiz.edu.tr/kisiler/tam-zamanli-ogretim-uyeleri#main-content
# Fetching URL: https://enm.yildiz.edu.tr/kisiler/arastirma-gorevlileri#main-content
# Fetching URL: https://enm.yildiz.edu.tr/kisiler/muhendisler#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisans#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisans/bolum-komisyonlari#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisans/erasmus#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisans/tezproje-yazim-klavuzlari#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisans/ogrenci-temsilciligi#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisans/intibak-basvurulari#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisans/formlar#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisans/staj-genel-bilgiler#main-content
# Error processing http://www.enm.yildiz.edu.tr/images/files/MASII_Instructions_EN_20072020.pdf: cannot open broken document
# Error processing file:///C:/Users/Supervisor/Downloads/MAKSTAJ_036%20(1).pdf: No connection adapters were found for 'file:///C:/Users/Supervisor/Downloads/MAKSTAJ_036%20(1).pdf'
# Fetching URL: https://enm.yildiz.edu.tr/lisans/mesleki-alan-staji-1
# Fetching URL: https://enm.yildiz.edu.tr/lisans/atolye-staji#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisans/mesleki-alan-staji-2#main-content
# Error processing file:///sites/enm.yildiz.edu.tr/images/files/MAS-II%20Yonerge%20Ingilizce.pdf: No connection adapters were found for 'file:///sites/enm.yildiz.edu.tr/images/files/MAS-II%20Yonerge%20Ingilizce.pdf'
# Fetching URL: https://enm.yildiz.edu.tr/lisans/staj-uygulama-ilkeleri#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisansustu#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisansustu/bilimsel-hazirlik-dersleri#main-content
# Fetching URL: https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/images/Bilimsel Hazırlık Dersleri.pdf
# Fetching URL: https://enm.yildiz.edu.tr/lisansustu/yonetmelikler-0#main-content
# Fetching URL: https://enm.yildiz.edu.tr/adaylar#main-content
# Fetching URL: https://enm.yildiz.edu.tr/ogrenci-bilgi-sistemleri#main-content
# Fetching URL: https://enm.yildiz.edu.tr/akademik-takvim#main-content
# Fetching URL: https://enm.yildiz.edu.tr/ders-programlari#main-content
# Fetching URL: https://enm.yildiz.edu.tr/sinav-programlari#main-content
# Fetching URL: https://enm.yildiz.edu.tr/akreditasyon#main-content
# Fetching URL: https://enm.yildiz.edu.tr/staj-ve-imkanlari#main-content
# Fetching URL: https://enm.yildiz.edu.tr/koop#main-content
# Fetching URL: http://www.koop.yildiz.edu.tr/haberler/24/2023-2024-Bahar-D%C3%B6nemi-KOOP-E%C4%9Fitimi-Takvimi
# Fetching URL: https://enm.yildiz.edu.tr/iletisim#main-content
# Fetching URL: https://enm.yildiz.edu.tr/lisans/mesleki-alan-staji-1#main-content

# %%
len(fetched_urls)
# Out:
# 109

# %%
for i in fetched_urls:
    if fetched_urls[i] == 'PDF':
        print(i)
# Out:
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/2-PÇ Ders İlişki Matrisi (GENEL) 02_03_2022.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/endustri-muhendisligi-bolumu-komisyonlari.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/Erasmus_Surecleri.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/O%CC%88g%CC%86renci%20Temsilcilig%CC%86i.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/Ogrenci Konseyi Yonergesi(1).pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/inline-files/Staj%2BYonergesi_%2025092023.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/2024-02/2023-2024-bahar-donemi-makine-fakultesi-basvuru-ilkeleri-ve-alinan-kararlar.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/2024-02/makstaj_036-1.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/2024-02/2023-2024-bahar-donem-staj-takvim-1.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/inline-files/Ato%CC%88lye%20Staj%C4%B1%20Yo%CC%88nergesi%20Tu%CC%88rkc%CC%A7e_0.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/inline-files/Ato%CC%88lye%20Staj%C4%B1%20Yo%CC%88nergesi%20I%CC%87ngilizce_0.pdf
# https://www.yok.gov.tr/Documents/Kurumsal/strateji_dairesi/mevzuat/YÜKSEKÖĞRETİM%20KURUMLARI%20KISMİ%20ZAMANLI%20ÖĞRENCİ%20ÇALIŞTIRMA%20USUL%20VE%20ESASLARI.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/lisans_0.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/lisansustu-i_0.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/lisansustu-ii-1_0.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/lisansustu-iii_1.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/Lisansüstü.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/Vize.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/Final_v7(1).pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/Mkt & Scouting Intern.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/2024-01/ytu.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/2024-01/fakulte-komisyon-listesi-ve-gorev-tanimlari-icin_2024.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/2024-01/bolum-komisyonu-listesi-ve-gorev-tanimlari-icin.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/files/inline-files/V6.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/0-MAS1 ESASLARI.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/MAS1 PRINCIPLES.docx.pdf
# https://enm.yildiz.edu.tr/sites/enm.yildiz.edu.tr/images/files/0-Sıkça Sorulan Sorular.pdf
# http://www.koop.yildiz.edu.tr/media/files/KOOP%202024%20BAHAR%20TAKV%C4%B0M%C4%B0.pdf

# %% [markdown]
# ### Saving urls dictionary

# %%
import pickle


# Save dictionary to a file
with open('../data/end_page_urls.pickle', 'wb') as handle:
    pickle.dump(fetched_urls, handle, protocol=pickle.HIGHEST_PROTOCOL)

# # Load dictionary from the file
# with open('data/erasmus_page_urls.pickle', 'rb') as handle:
#     loaded_dict = pickle.load(handle)

# print(loaded_dict)
